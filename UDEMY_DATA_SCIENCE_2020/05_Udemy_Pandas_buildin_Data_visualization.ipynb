# %% [markdown]
# ## May 09, 2020

# %% [markdown]
# ## This is the pandas build in data visualization course + Plotly and Cufflinks + Geographical Plotting

# %% [markdown]
# ##  Course by Udemy

# %% [markdown]
# ### ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Pandas Built-in Data Visualization
#
# In this lecture we will learn about pandas built-in capabilities for data visualization! It's built-off of matplotlib, but it baked into pandas for easier usage!
#
# Let's take a look!

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns

# %% [markdown]
# ## The Data
#
# There are some fake data csv files you can read in as dataframes:

# %%
df1 = pd.read_csv('df1',index_col=0)
df2=pd.read_csv('df2')

# %% [markdown]
# ### Style Sheets
#
# Matplotlib has [style sheets](http://matplotlib.org/gallery.html#style_sheets) you can use to make your plots look a little nicer. These style sheets include plot_bmh,plot_fivethirtyeight,plot_ggplot and more. They basically create a set of style rules that your plots follow. I recommend using them, they make all your plots have the same look and feel more professional. You can even create your own if you want your company's plots to all have the same look (it is a bit tedious to create on though).
#
# Here is how to use them.
#
# **Before plt.style.use() your plots look like this:**

# %%
df1.head()#The index is a time series
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()
#Will make the histogram of all of the vsalues in the "A" column

# %% [markdown]
# The histogram is using the matplotlib  libraries. So, we can use the matplotlib functions. For example, lets use the bin numbber

# %%
df1['A'].hist(bins=20,color='r')

# %% [markdown]
# ### BAsically there are two methods to plot the histogram by using pandas

# %% [markdown]
# You can call a dataframeitself or you can call acolumn in the data frame

# %% [markdown]
# #### Let us call the column first

# %%
df1['A'].plot(kind='hist')

# %% [markdown]
# ###### With this syntax we can add the histogram arguments such as bins

# %%
df1['A'].plot(kind='hist', bins = 30)

# %% [markdown]
# ###### Other  way of plotting histogram by usingb the pandas

# %%
df1['A'].plot.hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# ### Plot Types
#
# There are several plot types built-in to pandas, most of them statistical plots by nature:
#
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie
#
# You can also just call df.plot(kind='hist') or replace that kind argument with any of the key terms shown in the list above (e.g. 'box','barh', etc..)
# ___

# %%
df2.plot.area()# can pass some arguments as well

# %%
df2.plot.area(alpha=0.6) # showing the area of the values

# %%
df2.plot.bar() # index values are taken as category

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# ## Histogrmas

# %%
df1['A'].plot.hist(bins=50)

# %% [markdown]
# ## line plot

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
# do not understand the error in the line plot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ce40ab214708> in <module>
# ----> 1 df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwds)
#    3003             >>> lines = df.plot.line(x='pig', y='horse')
#    3004         """
# -> 3005         return self(kind='line', x=x, y=y, **kwds)
#    3006
#    3007     def bar(self, x=None, y=None, **kwds):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %% [markdown]
# ## Scatter plot

# %%
df1.plot.scatter(x='A',y='B',c='c') # c = c means color is equal to column c

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %% [markdown]
# some time people don't like to show them by color but they like to show the plot by the size

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']) #s represent the size of the data point
# Out:
# /home/bishnu/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# since the point sin the above plot are very small. SO multiply by some sort of factor

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*25)

# %% [markdown]
# ## BoxPlots

# %%
df2.plot.box()

# %% [markdown]
# ## Hexagonal Bin Plot
#
# Useful for Bivariate Data, alternative to scatterplot:

# %% [markdown]
# Let us create the data here

# %%
df= pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.plot.hexbin(x='a',y='b')

# %% [markdown]
# very small points. Lets increase the  size of the points

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %% [markdown]
# ## Kernel Density Estimation plot (KDE)

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()

# %% [markdown]
# can add more data points here

# %%
df2.plot.kde()

# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df3= pd.read_csv('df3')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
df3.plot.scatter(x='a',y='b',color='r',s=50,figsize=(12,3))
plt.xlim(-0.2,1.2)# sis the size
plt.ylim(-0.2,1.2)
# Out:
# (-0.2, 1.2)

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
df3['a'].hist(bins=25,color='r')

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df3['a'].hist(bins=25,color='r',alpha=0.3)

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
df3[['a','b']].plot.box()

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
df3['d'].plot.density(color='r')

# %%
df3['d'].plot.kde(color='r')

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
df3['d'].plot.kde(color='r',lw=5,ls=':')

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
df3.ix[0:30].plot.area(alpha=0.6)
# Out:
# /home/bishnu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
f = plt.figure()
df3.ix[0:30].plot.area(alpha=0.4,ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
# Out:
# /home/bishnu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# # Plotly and Cufflinks

# %% [markdown]
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images).
#
# ## Installation
#
# In order for this all to work, you'll need to install plotly and cufflinks to call plots directly off of a pandas dataframe. These libraries are not currently available through **conda** but are available through **pip**. Install the libraries at your command line/terminal using:
#
#     pip install plotly
#     pip install cufflinks
#
# ** NOTE: Make sure you only have one installation of Python on your computer when you do this, otherwise the installation may not work. **
#
# ## Imports and Set-up

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# PLEASE READ THIS! DON"T SKIP!
#
# Hi Everyone!
#
# There have been some recent updates to Plotly in May of 2020 which I wanted to let you know about! There's over 300,000 students in this course, so a lot of students are still running older versions of our files and libraries, so it makes it hard to strike a balance between new users on the latest updates and the majority of students still on older versions. So we've kept the videos and notebooks to match what "older" students will see, and here are 3 changes you will have to do if you are watching this post May 2020:
#
# 1. Possible Import Error 1: You need to install a new package. In your command line type and run:
#
# pip install chart-studio
#
# Then in jupyter make sure you import it by running the code:
#
# import chart_studio.plotly as py
#
#
# 2.Possible Colorscale Error 2: In the "Real Data US Map Choropleth", when you are creating the data dictionary, make sure the colorscale line is = 'ylorbr', not 'YIOrbr'... so like this:
#
# colorscale='ylorbr'
#
#
# 3.Possible projection Error 3: In the "World Map Choropleth", when you are creating the layout, ensure that your projection line is = {'type':'mercator'} not Mercator with a capital...so like this:
#
# projection={'type':'mercator'}
#
#
# Please search the QA forums before posting a new question on this, as there are already quite a few answered posts.
#
# Thanks!

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 4.7.1

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# This is going to connect to the javascript to your notebook because plotless essentially just connects
# pandas and python to the java script
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
#This will allows cufflinksoff line
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Lets creae the data first

# %%
df_1 = pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])
# randn means the normal  distribution
#(100,4) means the 100 rows and 4 columns

# %%
df_1.head()
# Out:
#           A         B         C         D
# 0 -0.177020 -0.396139  0.474676  0.450041
# 1  0.165165 -0.218115 -0.156272  0.011519
# 2  0.595539 -1.046823  0.571089 -0.423876
# 3 -1.262385  0.638783  0.631459 -0.259800
# 4  0.187590  1.236434 -1.333305 -1.082202

# %% [markdown]
# ### going to create one more data frame

# %%
df_2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df_2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Using Cufflinks and iplot()
#
# * scatter
# * bar
# * box
# * spread
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %% [markdown]
# ## Line plot

# %%
df_1.plot() # tha pandas made the following plot by using the matplotlib

# %%
df_1.iplot() # i is placed infront of the plot function
# very interesting, any place you put a cursor in the histogram, will get a numerical value eg.(48,0.01)
#Can zoom the plot like  in the root histogram and by double clicking come back to the original condition
# Also in the top right there are so many tools that allow you to save the histogram or download the histogram
# actually these tools shows when the cursor is close to the top right corner
# can on  and  off the data for example do not like to see the data by 'D' just click the D(legend)
# in order to see the dT from the D column, double click the D(legend)again
# Out:
# <div>
#
#
#             <div id="b676f047-1f86-4b21-93b1-0ea34139c8fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b676f047-1f86-4b21-93b1-0ea34139c8fc")) {
#                     Plotly.newPlot(
#                         'b676f047-1f86-4b21-93b1-0ea34139c8fc',
# ...

# %% [markdown]
# It was the most basic plot of the cufflink and that of the iplot.
# we can do many tipes lime bar, box maps snd more

# %% [markdown]
# ## Scatter plot

# %%
df_1.iplot(kind='scatter', x='A',y='B')
# In the following plot by default, a line is comnnecting all of the points
# Out:
# <div>
#
#
#             <div id="60b47695-62de-4786-bc16-89ad726e5d7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("60b47695-62de-4786-bc16-89ad726e5d7b")) {
#                     Plotly.newPlot(
#                         '60b47695-62de-4786-bc16-89ad726e5d7b',
# ...

# %% [markdown]
# To get the scatter plot you have to specify the mode ='markers'

# %%
df_1.iplot(kind='scatter', x='A',y='B',mode='markers')
# Out:
# <div>
#
#
#             <div id="e94430d2-86cb-4473-9fef-b3dc7f7e9f37" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e94430d2-86cb-4473-9fef-b3dc7f7e9f37")) {
#                     Plotly.newPlot(
#                         'e94430d2-86cb-4473-9fef-b3dc7f7e9f37',
# ...

# %% [markdown]
# #### Cana pass some more  arguments

# %%
df_1.iplot(kind='scatter', x='A',y='B',mode='markers',size=20,color='blue')
# Out:
# <div>
#
#
#             <div id="058f59ce-c9c2-4aa1-a8c5-e5838c5b4870" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("058f59ce-c9c2-4aa1-a8c5-e5838c5b4870")) {
#                     Plotly.newPlot(
#                         '058f59ce-c9c2-4aa1-a8c5-e5838c5b4870',
# ...

# %% [markdown]
# #### Lets us make a bar plot

# %%
df_2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="604646c3-215a-49c4-b336-ea6337cca7d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("604646c3-215a-49c4-b336-ea6337cca7d9")) {
#                     Plotly.newPlot(
#                         '604646c3-215a-49c4-b336-ea6337cca7d9',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %% [markdown]
# Now as we know data is not always going to  be conveniently placed such as df_2 if a category in Values column but which you can do is called group by an aggregate function on our data to actually get it into some sort of form where it makes sense to use a bar plot using i-plot

# %% [markdown]
# lets do in the details

# %%
df_1.head()
# Out:
#           A         B         C         D
# 0 -0.177020 -0.396139  0.474676  0.450041
# 1  0.165165 -0.218115 -0.156272  0.011519
# 2  0.595539 -1.046823  0.571089 -0.423876
# 3 -1.262385  0.638783  0.631459 -0.259800
# 4  0.187590  1.236434 -1.333305 -1.082202

# %% [markdown]
# in df_1 we have A, B,C and D. We wouldn't be able to call the bar plot of this otherwise we will just get a bunch of bars. Lets see the following histogram.

# %%
df_1.iplot(kind='bar') 
# you will get a  bunch of bars for every single data point
# Out:
# <div>
#
#
#             <div id="fc47d348-b024-4ddc-9353-04f88fdb389b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fc47d348-b024-4ddc-9353-04f88fdb389b")) {
#                     Plotly.newPlot(
#                         'fc47d348-b024-4ddc-9353-04f88fdb389b',
# ...

# %% [markdown]
# We need to do some sort of the aggregate function on top of this for  instance lets see you want to count the instance for each column

# %%
df_1.count().iplot(kind='bar')
# evenly distributed
# Out:
# <div>
#
#
#             <div id="a1353aff-84bb-4f9d-87fa-83e761f7ede1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a1353aff-84bb-4f9d-87fa-83e761f7ede1")) {
#                     Plotly.newPlot(
#                         'a1353aff-84bb-4f9d-87fa-83e761f7ede1',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %%
df_1.sum().iplot(kind='bar') # it printed in the opposite way, should print in the normal way
# Out:
# <div>
#
#
#             <div id="85f15328-0b8b-441c-a599-d4a583444f5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("85f15328-0b8b-441c-a599-d4a583444f5a")) {
#                     Plotly.newPlot(
#                         '85f15328-0b8b-441c-a599-d4a583444f5a',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [-11.453299301059076, -3.310139596461357, -8.717990037146617, -4.87641922485226]}],
# ...

# %% [markdown]
# ## Box plot

# %% [markdown]
# #### Box plot will automaticall that sort of the aggregation for the distribution

# %%
df_1.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="c7f9ed21-7f19-489b-b8c8-e3aea0efcaed" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c7f9ed21-7f19-489b-b8c8-e3aea0efcaed")) {
#                     Plotly.newPlot(
#                         'c7f9ed21-7f19-489b-b8c8-e3aea0efcaed',
# ...

# %% [markdown]
# ### Now lets talk about the 3 D surface  plot

# %%
df_3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,40,50],'z':[500,400,300,200,100]})

# %%
df_3 #this is 3 variables can  be a 3 dimensioanl plot
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  40  200
# 4  5  50  100

# %% [markdown]
# ##### Lets create a 3 dimensional surface plot of this data

# %%
df_3.iplot(kind='surface')
#has nice features like you can rotate, zoom or so
# Out:
# <div>
#
#
#             <div id="8b1bdfbd-70ba-413e-8560-025a29f156c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8b1bdfbd-70ba-413e-8560-025a29f156c4")) {
#                     Plotly.newPlot(
#                         '8b1bdfbd-70ba-413e-8560-025a29f156c4',
# ...

# %%
df_4 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,40,50],'z':[5,4,3,2,1]})
df_4.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="ecf92668-e21c-4804-ac33-873cfc6f840b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ecf92668-e21c-4804-ac33-873cfc6f840b")) {
#                     Plotly.newPlot(
#                         'ecf92668-e21c-4804-ac33-873cfc6f840b',
# ...

# %%
df_4.iplot(kind='surface',colorscale='rdylbu')

# rd for red, yl for yellow and bu for blue
# Out:
# <div>
#
#
#             <div id="acd381ab-9e30-4bb7-976a-074f6ffd0db7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("acd381ab-9e30-4bb7-976a-074f6ffd0db7")) {
#                     Plotly.newPlot(
#                         'acd381ab-9e30-4bb7-976a-074f6ffd0db7',
# ...

# %%
df_1['A'].iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="30dee398-4331-40e0-97f5-183ea852b943" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("30dee398-4331-40e0-97f5-183ea852b943")) {
#                     Plotly.newPlot(
#                         '30dee398-4331-40e0-97f5-183ea852b943',
# ...

# %% [markdown]
# ### Can specify the number of bins for another arguments

# %%
df_1['A'].iplot(kind='hist',bins=50)
# Out:
# <div>
#
#
#             <div id="9de3a1a4-2f82-4ed1-9409-1c44f810482b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9de3a1a4-2f82-4ed1-9409-1c44f810482b")) {
#                     Plotly.newPlot(
#                         '9de3a1a4-2f82-4ed1-9409-1c44f810482b',
# ...

# %% [markdown]
# ### Let us pass the entire dataframe

# %%
df_1.iplot(kind='hist')
# will be an overlaping histogram of all of the columns
# you can turn on oand off them by clicking them
# Out:
# <div>
#
#
#             <div id="92598f9f-23aa-4c18-bc8e-4645cad04b9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("92598f9f-23aa-4c18-bc8e-4645cad04b9f")) {
#                     Plotly.newPlot(
#                         '92598f9f-23aa-4c18-bc8e-4645cad04b9f',
# ...

# %% [markdown]
# ###### Next is the spread type of the visualisations which are used for the stock data

# %%
df_1[['A','B']].head()
# Out:
#           A         B
# 0 -0.177020 -0.396139
# 1  0.165165 -0.218115
# 2  0.595539 -1.046823
# 3 -1.262385  0.638783
# 4  0.187590  1.236434

# %%
df_1[['A','B']].iplot(kind='spread')
# Will get a plot and that of a sub  plot
# Out:
# <div>
#
#
#             <div id="604ffb57-def7-407c-b619-33e4f2791cd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("604ffb57-def7-407c-b619-33e4f2791cd3")) {
#                     Plotly.newPlot(
#                         '604ffb57-def7-407c-b619-33e4f2791cd3',
# ...

# %% [markdown]
# ##### Bubble plot

# %% [markdown]
# bubble plot is very similar to ascatter plot except that will change the size of the points based off of another varfiable

# %%
df_1.iplot(kind='bubble',x='A',y='B',size='C')
# size of the bubble is based on the other column value
# These plots are quite familier to represent happyness or something like that
# or these plots are quite famous in United nations report
# Out:
# <div>
#
#
#             <div id="8a601b61-ded0-4931-b990-ae4f36a5495c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8a601b61-ded0-4931-b990-ae4f36a5495c")) {
#                     Plotly.newPlot(
#                         '8a601b61-ded0-4931-b990-ae4f36a5495c',
# ...

# %% [markdown]
# ## Finally we will get to the scatter matrix

# %% [markdown]
# ###### The scattere  matrix plot is essentially very similar to seaborn pair plot

# %%
df_1.scatter_matrix()
# you may need to make sure all of your columns  are  numerical in order to do work
# Out:
# <div>
#
#
#             <div id="d7168544-934f-45f9-a7e2-bd829b8d011c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d7168544-934f-45f9-a7e2-bd829b8d011c")) {
#                     Plotly.newPlot(
#                         'd7168544-934f-45f9-a7e2-bd829b8d011c',
# ...

# %% [markdown]
# #### For more details visit the github/cufflinks page

# %% [markdown]
# # Geographical Plotting

# %% [markdown]
# ### The  Geographical Plotting is challenging due to varous formats the data can come in

# %% [markdown]
# #### We will focus on Plotly for plotting.

# %% [markdown]
# #### Matplotlib also has a basemap extension which allows geographical plots using Matplotlib

# %% [markdown]
# ## Choropleth Maps

# %% [markdown]
# ###### Get imports and set everything up to be working offline.

# %% [markdown]
# ### import plotly.plotly as py    ----> gave me am error and then I installed the following command

# %% [markdown]
# ##### conda install -c plotly plotly chart-studio

# %%
import chart_studio.plotly as py

# %%
import plotly.graph_objs as go

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %% [markdown]
# Now set up everything so that the figures show up in the notebook:

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# More info on other options for Offline Plotly usage can be found [here](https://plot.ly/python/offline/).

# %% [markdown]
# ## Choropleth US Maps
#
# Plotly's mapping can be a bit hard to get used to at first, remember to reference the cheat sheet in the data visualization folder, or [find it online here](https://images.plot.ly/plotly-documentation/images/python_cheat_sheet.pdf).

# %%
import pandas as pd

# %% [markdown]
# Now we need to begin to build our data dictionary. Easiest way to do this is to use the **dict()** function of the general form:
#
# * type = 'choropleth',
# * locations = list of states
# * locationmode = 'USA-states'
# * colorscale=
#
# Either a predefined string:
#
#     'pairs' | 'Greys' | 'Greens' | 'Bluered' | 'Hot' | 'Picnic' | 'Portland' | 'Jet' | 'RdBu' | 'Blackbody' | 'Earth' | 'Electric' | 'YIOrRd' | 'YIGnBu'
#
# or create a [custom colorscale](https://plot.ly/python/heatmap-and-contour-colorscales/)
#
# * text= list or array of text to display per point
# * z= array of values on z axis (color of state)
# * colorbar = {'title':'Colorbar Title'})
#
# Here is a simple example:

# %%
data = dict(type = 'choropleth',
            locations=['Az','CA','NY'],
            locationmode='USA-states',
            colorscale='Portland',
            text =['text1','text2','text3'],
            z=[1.0,2.0,3.0],
            colorbar={'title':'Colorbar Title'})

# %%
data
# Out:
# {'type': 'choropleth',
#  'locations': ['Az', 'CA', 'NY'],
#  'locationmode': 'USA-states',
#  'colorscale': 'Portland',
#  'text': ['text1', 'text2', 'text3'],
#  'z': [1.0, 2.0, 3.0],
#  'colorbar': {'title': 'Colorbar Title'}}

# %% [markdown]
# Then we create the layout nested dictionary:

# %%
layout = dict(geo = {'scope':'usa'}) # nested dictionary

# %%
layout
# Out:
# {'geo': {'scope': 'usa'}}

# %% [markdown]
# Then we use:
#
#     go.Figure(data = [data],layout = layout)
#
# to set up the object that finally gets passed into iplot()

# %%
choromap = go.Figure(data = [data],layout = layout)

# %%
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="c7d57bba-f0b1-446e-b7eb-a6251139ac1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c7d57bba-f0b1-446e-b7eb-a6251139ac1e")) {
#                     Plotly.newPlot(
#                         'c7d57bba-f0b1-446e-b7eb-a6251139ac1e',
#                         [{"colorbar": {"title": {"text": "Colorbar Title"}}, "colorscale": [[0.0, "rgb(12,51,131)"], [0.25, "rgb(10,136,186)"], [0.5, "rgb(242,211,56)"], [0.75, "rgb(242,143,56)"], [1.0, "rgb(217,30,30)"]], "locationmode": "USA-states", "locations": ["Az", "CA", "NY"], "text": ["text1", "text2", "text3"], "type": "choropleth", "z": [1.0, 2.0, 3.0]}],
# ...

# %%
data1 = dict(type = 'choropleth', # first object
            locations=['Az','CA','NY'], # list of states
            locationmode='USA-states',
            colorscale='Jet', # changed
            text =['text1','text2','text3'],
            z=[1.0,2.0,3.0],
            colorbar={'title':'Colorbar Title'})

# %%
layout1 = dict(geo = {'scope':'usa'})#second object

# %%
choromap1 = go.Figure(data = [data1],layout = layout1)
#passing to go

# %%
iplot(choromap1)
# Out:
# <div>
#
#
#             <div id="f20e4ab2-4ac0-47dd-84b6-e0b5d0e35322" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f20e4ab2-4ac0-47dd-84b6-e0b5d0e35322")) {
#                     Plotly.newPlot(
#                         'f20e4ab2-4ac0-47dd-84b6-e0b5d0e35322',
#                         [{"colorbar": {"title": {"text": "Colorbar Title"}}, "colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]], "locationmode": "USA-states", "locations": ["Az", "CA", "NY"], "text": ["text1", "text2", "text3"], "type": "choropleth", "z": [1.0, 2.0, 3.0]}],
# ...

# %% [markdown]
# ### Real Data US Map Choropleth
#
# Now let's show an example with some real data as well as some other options we can add to the dictionaries in data and layout.

# %%
df_5 = pd.read_csv('2011_US_AGRI_Exports')

# %%
df_5.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton  \
# 0          14.33  34.9   70.0   317.61
# ...

# %% [markdown]
# lets create the data and that of the layout variable

# %%
data_5 = dict(type='choropleth',
            # colorscale = 'YIOrRd',             
             locations=df_5['code'],            
             locationmode='USA-states',
             z=df_5['total exports'],
            # test=df_5['text'],
            # marker=dict(line=dict(color='rgb(255,255)',width=2)),
             colorbar={'title':'Millions USD'})

# %%
layout_5 = dict(title = '2011 US Agriculture Exports by State',
              geo = dict(scope='usa',
                         showlakes = True,
                         lakecolor = 'rgb(85,173,240)')
             )

# %%
choromap2 = go.Figure(data = [data_5],layout = layout_5) # disoplayed the error which I do not under stand

# %%
iplot(choromap2)
# Out:
# <div>
#
#
#             <div id="64342e4b-130e-4b3c-8658-e76df9195723" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("64342e4b-130e-4b3c-8658-e76df9195723")) {
#                     Plotly.newPlot(
#                         '64342e4b-130e-4b3c-8658-e76df9195723',
# ...

# %% [markdown]
# ## Choropleth Maps Part2 - International

# %%
df_6 = pd.read_csv('2014_World_GDP')
df_6.head()
# Out:
#           COUNTRY  GDP (BILLIONS) CODE
# 0     Afghanistan           21.71  AFG
# 1         Albania           13.40  ALB
# 2         Algeria          227.80  DZA
# 3  American Samoa            0.75  ASM
# 4         Andorra            4.80  AND

# %%
data6 = dict(type='choropleth',
             locations=df_6['CODE'],
             z=df_6['GDP (BILLIONS)'],
             text=df_6['COUNTRY'],
             colorbar={'title':'GDP in Billions USD'}
            )

# %%
layout6 = dict(title='2014 Global GDB',
                geo= dict(showframe=False,
                          projection = {'type':'Mercator'}))

# %%
layout_6
# Out:
# {'title': '2014 Global GDB',
#  'geo': {'showframe': False, 'projection': {'type': 'Mercator'}}}

# %%
choromap6 = go.Figure(data = [data6],layout = layout6) # do not understand the error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-362-acc5d4de121a> in <module>
# ----> 1 choromap6 = go.Figure(data = [data6],layout = layout6) # do not understand the error
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     582             is invalid AND skip_invalid is False
#     583         """
# --> 584         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     585
#     586     def add_area(
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     188         # ### Import Layout ###
#     189         self._layout_obj = self._layout_validator.validate_coerce(
# --> 190             layout, skip_invalid=skip_invalid, _validate=self._validate
# ...

# %% [markdown]
# # Choropleth Maps Exercise
#
# Welcome to the Choropleth Maps Exercise! In this exercise we will give you some simple datasets and ask you to create Choropleth Maps from them. Due to the Nature of Plotly we can't show you examples
#
# [Full Documentation Reference](https://plot.ly/python/reference/#choropleth)
#
# ## Plotly Imports

# %% [markdown]
# ** Import pandas and read the csv file: 2014_World_Power_Consumption**

# %%
df_a = pd.read_csv('2014_World_Power_Consumption')
df_a.head()
# Out:
#          Country  Power Consumption KWH                        Text
# 0          China           5.523000e+12     China 5,523,000,000,000
# 1  United States           3.832000e+12    United 3,832,000,000,000
# 2       European           2.771000e+12  European 2,771,000,000,000
# 3         Russia           1.065000e+12    Russia 1,065,000,000,000
# 4          Japan           9.210000e+11       Japan 921,000,000,000

# %%
data_a = dict(
        type = 'choropleth',
        #colorscale = 'Viridis',
        reversescale = True,
        locations = df_a['Country'],
        locationmode = "country names",
        z = df_a['Power Consumption KWH'],
        text = df_a['Country'],
       # colorbar = {'title' : 'Power Consumption KWH'},
      ) 

layout_a = dict(title = '2014 Power Consumption KWH',
                geo = dict(showframe = False,projection = {'type':'Mercator'})
             )

# %%
choromap = go.Figure(data = [data_a],layout = layout_a)
plot(choromap,validate=False)choromap = go.Figure(data = [data_a],layout = layout_a)
plot(choromap,validate=False)
# Out:
#   File "<ipython-input-368-4bfd15641d24>", line 2
#     plot(choromap,validate=False)choromap = go.Figure(data = [data_a],layout = layout_a)
#                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## No idea about the above error

# %% [markdown]
# ## USA Choropleth
#
# ** Import the 2012_Election_Data csv file using pandas. **

# %%
usdf = pd.read_csv('2012_Election_Data')

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
usdf.head()
# Out:
#    Year  ICPSR State Code  Alphanumeric State Code       State  \
# 0  2012                41                        1     Alabama
# 1  2012                81                        2      Alaska
# 2  2012                61                        3     Arizona
# 3  2012                42                        4    Arkansas
# 4  2012                71                        5  California
#
#   VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# 0                       NaN              58.6%              56.0%
# 1                     58.9%              58.7%              55.3%
# 2                     53.0%              52.6%              46.5%
# 3                     51.1%              50.7%              47.7%
# 4                     55.7%              55.1%              45.1%
#
#   Total Ballots Counted Highest Office Voting-Eligible Population (VEP)  \
# 0                   NaN      2,074,338                        3,539,217
# ...

# %% [markdown]
# ** Now create a plot that displays the Voting-Age Population (VAP) per state. If you later want to play around with other columns, make sure you consider their data type. VAP has already been transformed to a float for you. **

# %%
data_b = dict(type='choropleth',
            colorscale = 'Viridis',
            reversescale = True,
            locations = usdf['State Abv'],
            z = usdf['Voting-Age Population (VAP)'],
            locationmode = 'USA-states',
            text = usdf['State'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 1)),
            colorbar = {'title':"Voting-Age Population (VAP)"}
            )

# %%
layout_b = dict(title = '2012 General Election Voting Data',
              geo = dict(scope='usa',
                         showlakes = True,
                         lakecolor = 'rgb(85,173,240)')
             )

# %%
choromap_b = go.Figure(data = [data_b],layout = layout_b)
plot(choromap_b,validate=False)
# Out:
# 'temp-plot.html'

# %% [markdown]
# ##  In the above lines No error but the histogram displays in a differentg canvas
