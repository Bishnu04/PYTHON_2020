# %% [markdown]
# #### May 05, 2020

# %% [markdown]
# ### Data Visualization with Matplotlib

# %% [markdown]
# Matplotlib is the most popular plotting library fotr python.

# %% [markdown]
# It gives you control over every aspect of figure

# %% [markdown]
# It was designed to have a similar feel to MatLab's graphical plotting

# %% [raw]
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
#     Generally easy to get started for simple plots
#     Support for custom labels and texts
#     Great control of every element in a figure
#     High-quality output in many formats
#     Very customizable in general
#
# Matplotlib allows you to create reproducible figures programmatically. Let's learn how to use it! Before continuing this lecture, I encourage you just to explore the official Matplotlib web page: http://matplotlib.org/

# %% [markdown]
# ### Installation

# %% [markdown]
# You'll need to install matplotlib first with either:
#
# conda install matplotlib
#
# or pip install matplotlib

# %% [markdown]
# ### Importing

# %% [markdown]
# Import the matplotlib.pyplot module under the name plt (the tidy way):

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You'll also need to use this line to see plots in the notebook:

# %%
# %matplotlib inline

# %% [markdown]
# That line is only for jupyter notebooks, if you are using another editor, you'll use: plt.show() at the end of all your plotting commands to have the figure pop up in another window.

# %% [markdown]
# If you are not using ths jupyter notebook then use the following command to see the plot

# %% [markdown]
# plt.show()

# %% [markdown]
# ### Basic Example

# %% [markdown]
# Let's walk through a very simple example using two numpy arrays. You can also use lists, but most likely you'll be passing numpy arrays or pandas columns (which essentially also behave like arrays).

# %%
import numpy as np
x = np.linspace(0, 5, 11)# will be linearly spaced, we will go from 0 to 5 and then will rab 11 points
y = x ** 2

# %%
x # here x is an array of the elements from 0  to 5
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y #  array of the elements  that is the square of all of the x
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ## Two ways of creating the mat plot lib

# %% [markdown]
# #### functional method and object oriented method

# %% [markdown]
# ### Lets do the functionl method first

# %% [markdown]
# ### Basic Matplotlib Commands

# %% [markdown]
# We can create a very simple line plot using the following ( I encourage you to pause and use Shift+Tab along the way to check out the document strings for the functions we are using).

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
#plt.show()
# Out:
# Text(0.5, 1.0, 'String Title Here')

# %% [markdown]
# ### Creating Multiplots on Same Canvas

# %% [markdown]
# Signature: plt.subplot(*args, **kwargs)
# Docstring:
# Add a subplot to the current figure.
#
# Wrapper of `.Figure.add_subplot` with a difference in behavior
# explained in the notes section.
#
# Call signatures::
#
#    subplot(nrows, ncols, index, **kwargs)
#    subplot(pos, **kwargs)
#    subplot(ax)

# %% [markdown]
# #### plt.subplot(nrows,ncols,plot no you refering to)#

# %%
plt.subplot(1,2,1)# last 1 refered to the first plot number
plt.plot(x,y,'r')
plt.xlabel("subplot_1")

plt.subplot(1,2,2) # the last 2 refered to the plot number
plt.plot(y,x,'b')

# %% [markdown]
# ### We can do the same thing in the different way

# %% [markdown]
# #### just changing the row in to the column

# %%
plt.subplot(2,1,1)# last 1 refered to the first plot number
plt.plot(x,y,'g--')

plt.subplot(2,1,2) # the last 2 refered to the plot number
plt.plot(y,x,'m*')

# %% [markdown]
# ## Matplotlib Object Oriented Method

# %% [markdown]
# Now that we've seen the basics, let's break it all down with a more formal introduction of Matplotlib's Object Oriented API. This means we will instantiate figure objects and then call methods or attributes from that object.

# %% [markdown]
# ### Introduction to the Object Oriented Method

# %% [markdown]
# The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure:

# %% [markdown]
# #### Object oriented method

# %%
#00
fig = plt.figure() # means I have a figure object has been created

# %% [markdown]
# Note:The fig  object is like an empty canvas and we can add a set of access to it

# %% [markdown]
# #### axes =fig.add_axes([x1,y1,x2,y2]) just like the legend method in the C++

# %%
fig = plt.figure()# note do in the same cell
axes =fig.add_axes([0.1,0.1,0.8,0.8])# will create the blank cell
axes.plot()
# Out:
# []

# %% [markdown]
# #### Finally plot on that set of axis

# %%
fig = plt.figure()# note do in the same cell
axes =fig.add_axes([0.1,0.1,0.8,0.8])# will create the blank cell
axes.plot(x,y)

# %% [markdown]
# we can put the x lables, ylables and thitile in the above plot

# %%
fig = plt.figure()# note do in the same cell
axes =fig.add_axes([0.1,0.1,0.8,0.8])# will create the blank cell
axes.plot(x,y)
axes.set_xlabel('This is xlabel')
axes.set_ylabel('This is ylabel')
axes.set_title('This is titel')
# Out:
# Text(0.5, 1.0, 'This is titel')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
#0.2 means 20%from left, 0.5 means 50% from bottom , 0.4 means 40% from right and 0.3 means 
# 30% from top of above .
axes1.plot(x,y)
axes2.plot(y,x)

axes1.set_title('mainplot')
axes1.set_ylabel('This is main plot ylabel')
axes1.set_xlabel('This is main plot titel')

axes2.set_title('subplot')
axes2.set_ylabel('This is subplot ylabel')
axes2.set_xlabel('This is subplot titel')
# Out:
# Text(0.5, 0, 'This is subplot titel')

# %% [markdown]
# ## Matplotlib part2

# %% [markdown]
# #### How to create the subplots by using the object oriented programming

# %% [markdown]
# The plt.subplots() object will act as a more automatic axis manager.

# %%
fig_1,axes_1 = plt.subplots()
axes_1.plot(x,y)

# %%
fig_a,axes_a = plt.subplots(nrows=1,ncols=2) # 3 rows and 3 columns

# %%
fig_b,axes_b = plt.subplots(nrows=3,ncols=3) # 3 rows and 3 columns

# %% [markdown]
# The rows and that of the  columns are actually very close to each other. Ltes seperate them

# %%
fig_b,axes_b = plt.subplots(nrows=3,ncols=3) # 3 rows and 3 columns
plt.tight_layout()

# %% [markdown]
# Lets us go back to plot the 1 row and that of two columns

# %%
fig_a,axes_a = plt.subplots(nrows=1,ncols=2)

# %%
axes_a # arrary of the matplot lib
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f69a9784278>,
# ...
#       dtype=object)

# %% [markdown]
# ### To plot a data there are two ways for the subplot method.

# %% [markdown]
# #### 1. by iteration method

# %% [markdown]
# #### 2. Index method

# %% [markdown]
# #### Lets start with the iteration merhod first

# %%
fig_a,axes_a = plt.subplots(nrows=1,ncols=2)
for current_ax in axes_a:
    current_ax.plot(x,y,'r')
    current_ax.set_xlabel('x axis')
    current_ax.set_ylabel('y axis')
    current_ax.set_title('main title')

# %% [markdown]
# A common issue with matplolib is overlapping subplots or figures. We ca use fig.tight_layout() or plt.tight_layout() method, which automatically adjusts the positions of the axes on the figure canvas so that there is no overlapping content:

# %%
fig_a,axes_a = plt.subplots(nrows=1,ncols=2)
for current_ax in axes_a:
    current_ax.plot(x,y,'r')
    current_ax.set_xlabel('x axis')
    current_ax.set_ylabel('y axis')
    current_ax.set_title('main title')
plt.tight_layout()

# %% [markdown]
# #### lets use the index method as well

# %%
fig_a,axes_a = plt.subplots(nrows=1,ncols=2)
axes_a[0].plot(x,y,'g') #the fig with the index 0 is filled 
axes_a[1].plot(y,y,'r') # made a straight line
axes_a[0].set_title('First plot')
axes_a[1].set_title('2nd  plot')

plt.tight_layout()

# %% [markdown]
# ### Note: keep in mind that for the fig = plt.figure() method need to provide the list that is [x1,y1,x2,y2]. These gives the canvas size.
#
#
# axes1 = fig.add_axes([0.1,0.1,0.8,0.8])

# %% [markdown]
# #### For the subplot method we need to provide:    fig_a,axes_a = plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# ## Figure size, aspect ratio and DPI

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
#     figsize is a tuple of the width and height of the figure in inches
#     dpi is the dots-per-inch (pixel per inch).
#
# For example:

# %%
fig_3=plt.figure(figsize=(3,2),dpi=100)
ax=fig_3.add_axes([0,0,1,1])
ax.plot(x,y)

# %% [markdown]
# ### Lets change the size of the figure and how it looks like

# %%
fig_3=plt.figure(figsize=(8,2),dpi=100)
ax=fig_3.add_axes([0,0,1,1])
ax.plot(x,y)

# %% [markdown]
# ### we can do same thing for the subplot

# %%
fig_4,ax_1 = plt.subplots(figsize=(8,2))
ax_1.plot(x,y) # will ahve the similar figure

# %% [markdown]
# ### lets us specify some rows and columns for the subplot

# %%
fig_4,ax_1 = plt.subplots(nrows = 2,ncols=1,figsize=(8,2))
#ax_1.plot(x,y) # will ahve the similar figure
ax_1[0].plot(x,y)
ax_1[1].plot(y,x)

# %% [markdown]
# #### Lets separate the axis little bit

# %%
fig_4,ax_1 = plt.subplots(nrows = 2,ncols=1,figsize=(8,2))
#ax_1.plot(x,y) # will ahve the similar figure
ax_1[0].plot(x,y)
ax_1[1].plot(y,x)
plt.tight_layout()

# %% [markdown]
# ### Saving figures

# %% [markdown]
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %% [markdown]
# To save a figure to a file we can use the savefig method in the Figure class:

# %% [markdown]
# ### fig.savefig("filename.png")

# %% [markdown]
# Here we can also optionally specify the DPI and choose between different output formats:

# %% [markdown]
# #### fig.savefig("filename.png", dpi=200)

# %% [markdown]
# # Lets save the figure from the beginning

# %% [markdown]
# I have a following fig_3 plot

# %%
fig_3

# %%
fig_3.savefig('fig_3.pdf',dpi=200)
fig_3.savefig('fig_2.pdf',dpi=50)

# %% [markdown]
# ## Legends, labels and titles

# %% [markdown]
# Figure titles
#
# A title can be added to each axis instance in a figure. To set the title, use the set_title method in the axes instance:

# %%
ax.set_title("title");

# %% [markdown]
# ### Axis labels

# %% [markdown]
# Similarly, with the methods set_xlabel and set_ylabel, we can set the labels of the X and Y axes:

# %%
ax.set_xlabel("x")
ax.set_ylabel("y");

# %% [markdown]
# ## Legends

# %% [markdown]
# You can use the label="label text" keyword argument when plots or other objects are added to the figure, and then using the legend method without arguments to add the legend to the figure:

# %%
fig_5 = plt.figure()
ax_5=fig_5.add_axes([0,0,1,1])
ax_5.plot(x,x**2)
ax_5.plot(x,x**3)
ax_5.legend() # it prints aline below this line as the 
# labels are not given yet
# Out:
# No handles with labels found to put in legend.

# %%
fig_5 = plt.figure()
ax_5=fig_5.add_axes([0,0,1,1])
ax_5.plot(x,x**2,label ='x square')
ax_5.plot(x,x**3,label ='x cubed')
ax_5.legend()

# %% [markdown]
# ##### We can move the location of the legend

# %% [markdown]
# The locations for the legend are given to the following link

# %% [markdown]
# https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.legend.html

# %%
fig_5 = plt.figure()
ax_5=fig_5.add_axes([0,0,1,1])
ax_5.plot(x,x**2,label ='x square')
ax_5.plot(x,x**3,label ='x cubed')
ax_5.legend(loc=4) # this 4 can be varied according to the need . could be 0,1,2,3,4...10

# %% [markdown]
# can also give a position by the following way

# %%
fig_5 = plt.figure()
ax_5=fig_5.add_axes([0,0,1,1])
ax_5.plot(x,x**2,label ='x square')
ax_5.plot(x,x**3,label ='x cubed')
ax_5.legend(loc=(0.1,0.1))

# %% [markdown]
# ## Matplotlib- Part 3

# %% [markdown]
# ## Setting colors, linewidths, linetypes

# %% [markdown]
# Matplotlib gives you a lot of options for customizing colors, linewidths, and linetypes.
#
# There is the basic MATLAB like syntax (which I would suggest you avoid using for more clairty sake:

# %% [markdown]
# ### Colors with MatLab like syntax

# %% [markdown]
# With matplotlib, we can define the colors of lines and other graphical elements in a number of ways. First of all, we can use the MATLAB-like syntax where 'b' means blue, 'g' means green, etc. The MATLAB API for selecting line styles are also supported: where, for example, 'b.-' means a blue line with dots:

# %%
fig_6,ax_6 = plt.subplots()
ax_6.plot(x,x**2,'b.-')# blue line with dots
ax_6.plot(x,x**3,'g--')# green dashed line

# %% [markdown]
# ### Colors with the color= parameter

# %% [markdown]
# We can also define colors by their names or RGB hex codes and optionally provide an alpha value using the color and alpha keyword arguments. Alpha indicates opacity

# %%
fig_6,ax_6 = plt.subplots()
ax_6.plot(x,x+1,color='blue',alpha=0.5)# half-transparant
ax_6.plot(x,x+2,'--',color ="#8B008B")# RGB hex code can  Google
ax_6.plot(x,x+3,'*', color="#FF8C00")# RGB hex code

# %% [markdown]
# ## Line width and lime style

# %% [markdown]
# For the line width we don't have to type the linewidth  lw also works

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',linewidth=1) #default line width

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',lw=5) #default line width

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',linewidth=0.5)

# %% [markdown]
# #### I am adding alpha in this time which means how transparent it is

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',linewidth=5,alpha=0.3) #0.3 means 605 OF THE original

# %% [markdown]
# ## Line style

# %% [markdown]
# lets remove the alpha from the above code and talk about the line style

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',linewidth=5,linestyle='--')

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',linewidth=5,linestyle='-.')

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',linewidth=5,linestyle=':') #and so on

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',linewidth=5,linestyle='steps')

# %% [markdown]
# Note: for the linestyle no need to type the whole word linestyle, just can type the ls

# %% [markdown]
# ##### Markers are going to used when you have just few data   points

# %% [markdown]
# ###### x # lets see what is x and how is its length

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x) #just 11 points
# Out:
# 11

# %% [markdown]
# I am going to put the markers where the data points exist

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',lw=2,ls='-',marker='o')
# The lower case o produces the dots where the data points exist

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',lw=1,ls='-',marker='+')
# The lower case o produces the dots where the data points exist

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',lw=1,ls=':',marker='*')
# The lower case o produces the dots where the data points exist

# %% [markdown]
# #### lets make the markers bigger

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',lw=1,ls=':',marker='*',markersize=20)
# The lower case o produces the dots where the data points exist

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',lw=1,ls=':',marker='*',markersize=20,markerfacecolor='yellow')
# The lower case o produces the dots where the data points exist

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',lw=1,ls=':',marker='*',markersize=20,markerfacecolor='yellow',markeredgewidth=3)
# The lower case o produces the dots where the data points exist

# %%
fig_7 = plt.figure()
ax_7 =fig_7.add_axes([0,0,1,1])
ax_7.plot(x,y,color='purple',lw=1,ls=':',marker='*',markersize=20,markerfacecolor='yellow',
          markeredgewidth=3,markeredgecolor='green')
# The lower case o produces the dots where the data points exist

# %% [markdown]
# #### Here are some more options may be helpful in the future study

# %%
fig_8, ax_8 = plt.subplots(figsize=(12,6))

ax_8.plot(x, x+1, color="red", linewidth=0.25)
ax_8.plot(x, x+2, color="red", linewidth=0.50)
ax_8.plot(x, x+3, color="red", linewidth=1.00)
ax_8.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax_8.plot(x, x+5, color="green", lw=3, linestyle='-')
ax_8.plot(x, x+6, color="green", lw=3, ls='-.')
ax_8.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax_8.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax_8.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax_8.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax_8.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax_8.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax_8.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax_8.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax_8.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax_8.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# #### Control over axis appearance

# %% [markdown]
# In this section we will look at controlling axis sizing properties in a matplotlib figure.

# %% [markdown]
# ### Plot range

# %% [markdown]
# We can configure the ranges of the axes using the set_ylim and set_xlim methods in the axis object, or axis('tight') for automatically getting "tightly fitted" axes ranges:

# %%
fig_9 = plt.figure()
ax_9 =fig_9.add_axes([0,0,1,1])
ax_9.plot(x,y,color='purple',lw=3,ls=':')

# %%
fig_9 = plt.figure()
ax_9 =fig_9.add_axes([0,0,1,1])
ax_9.plot(x,y,color='purple',lw=3,ls=':')
ax_9.set_xlim([0,1])
ax_9.set_ylim([0,2])
# Out:
# (0, 2)

# %%
fig_9 = plt.figure()
ax_9 =fig_9.add_axes([0,0,1,1])
ax_9.plot(x,y,color='purple',lw=3,ls=':')
ax_9.set_xlim([0,10])
ax_9.set_ylim([0,29])
# Out:
# (0, 29)

# %% [markdown]
# ### Special Plot Types

# %% [markdown]
# There are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more. Most of these type of plots we will actually create using seaborn, a statistical plotting library for Python. But here are a few examples of these type of plots:

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([10., 10.,  6., 14., 10., 13.,  9.,  6., 13.,  9.]),
#  array([  6. , 105.1, 204.2, 303.3, 402.4, 501.5, 600.6, 699.7, 798.8,
#         897.9, 997. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# ### Further reading
#
#     http://www.matplotlib.org - The project web page for matplotlib.
#     https://github.com/matplotlib/matplotlib - The source code for matplotlib.
#     http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
#     http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
#     http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.

# %% [markdown]
# ## Matplotlib Exercises

# %% [markdown]
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **

# %% [markdown]
# ## Data

# %%
import numpy as np

# %%
a=np.arange(0,100)
b=a*2
c=a**2

# %% [markdown]
# ###### ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# ** Follow along with these steps: **
#
#     ** Create a figure object called fig using plt.figure() **
#     ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
#     ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig_A = plt.figure()
ax_A=fig_A.add_axes([0,0,1,1])
ax_A.plot(a,b)
ax_A.set_xlabel("this is x axis")
ax_A.set_ylabel("this is y axis")
ax_A.set_title("this is title")
# Out:
# Text(0.5, 1.0, 'this is title')

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# ###### ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig_B = plt.figure()
axes_B=fig_B.add_axes([0,0,1,1])
axes_B1=fig_B.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ##### ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig_B = plt.figure()
axes_B=fig_B.add_axes([0,0,1,1])
axes_B1=fig_B.add_axes([0.2,0.5,0.2,0.2])
axes_B.plot(a,b,'r')
axes_B1.plot(a,b,'r')
plt.show()

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig_c = plt.figure()
ax_c = fig_c.add_axes([0,0,1,1])
ax_c1 = fig_c.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# ###### ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig_c = plt.figure() 
ax_c = fig_c.add_axes([0,0,1,1])
ax_c1 = fig_c.add_axes([0.2,0.5,0.4,0.4])
ax_c.plot(a,c)
ax_c1.plot(a,b)
ax_c.set_xlabel(" x axis")
ax_c.set_ylabel(" z axis")
ax_c1.set_xlabel(" x axis")
ax_c1.set_ylabel(" y axis")
ax_c1.set_title("zoom")
ax_c1.set_xlim([20,22])
ax_c1.set_ylim([30,50])
# Out:
# (30, 50)

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# ##### ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
df_d,ax_d = plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# ##### ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
df_d,ax_d = plt.subplots(nrows=1,ncols=2)
ax_d[0].plot(a,b,color='blue',ls='--',linewidth=5)
ax_d[1].plot(a,c,color='r',linewidth=3)

# %% [markdown]
# ##### ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
df_d,ax_d = plt.subplots(nrows=1,ncols=2,figsize=(16,2))
ax_d[0].plot(a,b,color='blue',ls='--',linewidth=5)
ax_d[1].plot(a,c,color='r',linewidth=3,ls='--')
ax_d[0].set_title("title")
ax_d[0].set_xlabel("x axis")
ax_d[0].set_ylabel(" y axis")
# Out:
# Text(0, 0.5, ' y axis')

# %% [markdown]
# ### Advanced Matplotlib Concepts Lecture

# %% [markdown]
# In this lecture we cover some more advanced topics which you won't usually use as often. You can always reference the documentation for more resources!

# %% [markdown]
# ### Logarithmic scale

# %% [markdown]
# It is also possible to set a logarithmic scale for one or both axes. This functionality is in fact only one application of a more general transformation system in Matplotlib. Each of the axes' scales are set seperately using set_xscale and set_yscale methods which accept one parameter (with the value "log" in this case):

# %%
fig_g, ax_g=plt.subplots(1,2,figsize=(10,5))
ax_g[0].plot(x,x**2,x,np.exp(x))
ax_g[0].set_title("Normal Scale")

ax_g[1].plot(x,x**2,x,np.exp(x))
ax_g[1].set_yscale("log")# log scale defined here
ax_g[1].set_title("Logrethmic scale(y)")
# Out:
# Text(0.5, 1.0, 'Logrethmic scale(y)')

# %% [markdown]
# ## Placement of ticks and custom tick labels

# %% [markdown]
# We can explicitly determine where we want the axis ticks with set_xticks and set_yticks, which both take a list of values for where on the axis the ticks are to be placed. We can also use the set_xticklabels and set_yticklabels methods to provide a list of custom text labels for each tick location:

# %%
fig_h,ax_h = plt.subplots(figsize=(10,4))
ax_h.plot(x,x**2,x**3,lw=2)# lw is the line width

# %%
fig_h,ax_h = plt.subplots(figsize=(10,4))
ax_h.plot(x,x**2,x**3,lw=2)
ax_h.set_xticks([1,2,3,4,5])
ax_h.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', 
                      r'$\delta$', r'$\epsilon$'], fontsize=18)
yticks=[0,50,100,150]
ax_h.set_yticks(yticks)

# %%
fig_h,ax_h = plt.subplots(figsize=(10,4))
ax_h.plot(x,x**2,x**3,lw=2)
ax_h.set_xticks([1,2,3,4,5])
ax_h.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', 
                      r'$\delta$', r'$\epsilon$'], fontsize=18)
yticks=[0,50,100,150]
ax_h.set_yticks(yticks)
ax_h.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18);
# use LaTeX formatted lab

# %% [markdown]
# There are a number of more advanced methods for controlling major and minor tick placement in matplotlib figures, such as automatic placement according to different policies. See http://matplotlib.org/api/ticker_api.html for details.

# %% [markdown]
# ### Scientific notation

# %% [markdown]
# With large numbers on axes, it is often better use scientific notation:

# %%
fig_i, ax_i = plt.subplots(1, 1)
      
ax_i.plot(x,x**2, x, np.exp(x))
ax_i.set_title("scientific notation")
ax_i.set_yticks([0, 50, 100, 150])
from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax_i.yaxis.set_major_formatter(formatter)

# %% [markdown]
# ### Axis position adjustments

# %% [markdown]
# Unfortunately, when saving figures the labels are sometimes clipped, and it can be necessary to adjust the positions of axes a little bit. This can be done using subplots_adjust:

# %%
fig_j, ax_j = plt.subplots(1, 1)
      
ax_j.plot(x, x**2, x, np.exp(x))
ax_j.set_yticks([0, 50, 100, 150])

ax_j.set_title("title")
ax_j.set_xlabel("x")
ax_j.set_ylabel("y")

# fig_j.subplots_adjust(left=0.15, right=.9, bottom=0.1, top=0.9);
# Out:
# Text(0, 0.5, 'y')

# %%
fig_j, ax_j = plt.subplots(1, 1)
      
ax_j.plot(x, x**2, x, np.exp(x))
ax_j.set_yticks([0, 50, 100, 150])

ax_j.set_title("title")
ax_j.set_xlabel("x")
ax_j.set_ylabel("y")

fig_j.subplots_adjust(left=0.15, right=.9, bottom=0.1, top=0.9);

# %% [markdown]
# ### Axis grid

# %% [markdown]
# With the grid method in the axis object, we can turn on and off grid lines. We can also customize the appearance of the grid lines using the same keyword arguments as the plot function:

# %%
fig_k, axes_k = plt.subplots(1, 2, figsize=(10,3))

# default grid appearance
axes_k[0].plot(x, x**2, x, x**3, lw=2)
axes_k[0].grid(True)

# custom grid appearance
axes_k[1].plot(x, x**2, x, x**3, lw=2)
axes_k[1].grid(color='g', alpha=1, linestyle='-', linewidth=0.5)

# %% [markdown]
# ### Axis spines

# %% [markdown]
# We can also change the properties of axis spines:

# %%
fig_l, ax_l = plt.subplots(figsize=(6,2))

ax_l.spines['bottom'].set_color('blue')
ax_l.spines['top'].set_color('blue')

ax_l.spines['left'].set_color('r')
ax_l.spines['left'].set_linewidth(2)

# turn off axis spine to the right
ax_l.spines['right'].set_color("none")
ax_l.yaxis.tick_left() # only ticks on the left side

# %% [markdown]
# ### Twin axes

# %% [markdown]
# Sometimes it is useful to have dual x or y axes in a figure; for example, when plotting curves with different units together. Matplotlib supports this with the twinx and twiny functions:

# %%
fig_m, ax1_m = plt.subplots()

ax1_m.plot(x, x**2, lw=2, color="blue")
ax1_m.set_ylabel(r"area $(m^2)$", fontsize=18, color="blue")
for label in ax1_m.get_yticklabels():
    label.set_color("blue")
    
ax2 = ax1_m.twinx()
ax2.plot(x, x**3, lw=2, color="red")
ax2.set_ylabel(r"volume $(m^3)$", fontsize=18, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")

# %% [markdown]
# ### Axes where x and y is zero

# %%
fig_n, ax_n = plt.subplots()

ax_n.spines['right'].set_color('none')
ax_n.spines['top'].set_color('none')

ax_n.xaxis.set_ticks_position('bottom')
ax_n.spines['bottom'].set_position(('data',0)) # set position of x spine to x=0

ax_n.yaxis.set_ticks_position('left')
ax_n.spines['left'].set_position(('data',0))   # set position of y spine to y=0

xx = np.linspace(-0.75, 1., 100)
ax_n.plot(xx, xx**3);

# %% [markdown]
# ## Other 2D plot styles

# %% [markdown]
# In addition to the regular plot method, there are a number of other functions for generating different kind of plots. See the matplotlib plot gallery for a complete list of available plot types: http://matplotlib.org/gallery.html. Some of the more useful ones are show below:

# %%
n = np.array([0,1,2,3,4,5])

# %%
fig_o, axes_o = plt.subplots(1, 4, figsize=(12,3))

axes_o[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes_o[0].set_title("scatter")

axes_o[1].step(n, n**2, lw=2)
axes_o[1].set_title("step")

axes_o[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes_o[2].set_title("bar")

axes_o[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes_o[3].set_title("fill_between");

# %% [markdown]
# ## Text annotation

# %% [markdown]
# Annotating text in matplotlib figures can be done using the text function. It supports LaTeX formatting just like axis label texts and titles:

# %%
fig_p, ax_p = plt.subplots()

ax_p.plot(xx, xx**2, xx, xx**3)

ax_p.text(0.15, 0.2, r"$y=x^2$", fontsize=20, color="blue")
ax_p.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green");

# %% [markdown]
# ### Colormap and contour figures

# %% [markdown]
# Colormaps and contour figures are useful for plotting functions of two variables. In most of these functions we will use a colormap to encode one dimension of the data. There are a number of predefined colormaps. It is relatively straightforward to define custom colormaps. For a list of pre-defined colormaps, see: http://www.scipy.org/Cookbook/Matplotlib/Show_colormaps

# %%
import matplotlib.pyplot as plt
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

# %%
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %% [markdown]
# #### pcolor

# %%
fig, ax = plt.subplots()# something wrong

p = ax.pcolor(X/(2*np.pi), Y/(2*np.pi), Z, cmap=matplotlib.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())
cb = fig.colorbar(p, ax=ax)

# %% [markdown]
# ## 3D figures

# %% [markdown]
# To use 3D graphics in matplotlib, we first need to create an instance of the Axes3D class. 3D axes can be added to a matplotlib figure canvas in exactly the same way as 2D axes; or, more conveniently, by passing a projection='3d' keyword argument to the add_axes or add_subplot methods.

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %% [markdown]
# ### Surface plots

# %%
fig_r = plt.figure(figsize=(14,6))

# `ax` is a 3D-aware axis instance because of the projection='3d' keyword argument to add_subplot
ax_r = fig_r.add_subplot(1, 2, 1, projection='3d')

p = ax_r.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot with color grading and color bar
ax_r = fig_r.add_subplot(1, 2, 2, projection='3d')
p = ax_r.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig_r.colorbar(p, shrink=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-326-b5280996fe14> in <module>
#       8 # surface_plot with color grading and color bar
#       9 ax_r = fig_r.add_subplot(1, 2, 2, projection='3d')
# ---> 10 p = ax_r.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0, antialiased=False)
#      11 cb = fig_r.colorbar(p, shrink=0.5)
#
# NameError: name 'matplotlib' is not defined

# %% [markdown]
# ### Wire-frame plot

# %%
fig_s = plt.figure(figsize=(8,6))

ax_s = fig.add_subplot(1, 1, 1, projection='3d')

p = ax_s.plot_wireframe(X, Y, Z, rstride=4, cstride=4)

# %% [markdown]
# ### Coutour plots with projections

# %%
fig_t = plt.figure(figsize=(8,6))  #something wrong

ax_t = fig.add_subplot(1,1,1, projection='3d')

ax_t.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
cset = ax_t.contour(X, Y, Z, zdir='z', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
cset = ax_t.contour(X, Y, Z, zdir='x', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
cset = ax_t.contour(X, Y, Z, zdir='y', offset=3*np.pi, cmap=matplotlib.cm.coolwarm)

ax_t.set_xlim3d(-np.pi, 2*np.pi);
ax_t.set_ylim3d(0, 3*np.pi);
ax_t.set_zlim3d(-np.pi, 2*np.pi);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-328-88bc251beeb2> in <module>
#       4
#       5 ax_t.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
# ----> 6 cset = ax_t.contour(X, Y, Z, zdir='z', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
#       7 cset = ax_t.contour(X, Y, Z, zdir='x', offset=-np.pi, cmap=matplotlib.cm.coolwarm)
#       8 cset = ax_t.contour(X, Y, Z, zdir='y', offset=3*np.pi, cmap=matplotlib.cm.coolwarm)
#
# NameError: name 'matplotlib' is not defined
